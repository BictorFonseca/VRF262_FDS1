# %%
inp=999
import VF_stats_module as vf
lst=[]
while inp !=9:
    print("Press [0] to input a set of new numbers")
    print("Press [1] to find the mean")
    print("Press [2] to find the variance")
    print("Press [3] to find the standard deviation")
    print("Press [4] to find the standard error")
    print("Press [5] to find the Z-score of a new observation")
    print("Press [6] for the suammary of the statistics")
    print("Press [9] to exit")
    inp=int(input("Enter command: "))

    if inp == 0:
        lst=[]
        while inp!="done":
            inp=(input("Enter number (or done if you're done): "))
            if inp=="done":
                break
            else:
                try:
                    inp=int(inp)
                    lst.append(inp)
                except:
                    inp=input("Enter number (or done if you're done): ")
    elif(inp==1):
        #Mean
        if lst==[]:
            print("Please enter a set of numbers")
        else:
            print()
            print("Mean is", vf.co_mean(lst))
            print()
    elif(inp==2):
        #Var
        if lst==[]:
            print("Please enter a set of numbers")
        else:
            print()
            print("Variance is", vf.co_var(lst))
            print()
    elif(inp==3):
        #STD
        if lst==[]:
            
            print("Please enter a set of numbers")
        else:
            print()
            print("Standard deviation is", vf.co_std(lst))
            print()
    elif(inp==4):
        #SE
        if lst==[]:
            
            print("Please enter a set of numbers")
        else:
            print()
            print("Standard error is", vf.co_se(lst))
            print()
    elif(inp==5):
        #Z-Score
        if lst==[]:
            
            print("Please enter a set of numbers")
        else:
            
            n=input("Enter new observation: ")
            try:
                n=int(n)
                print()
                print("Z-Score is", vf.co_z(lst))
                print()
            except:
                
                inp=input("New Observation was not a number. Try again")
    elif(inp==6):
        #Sum.
        if lst==[]:
            
            print("Please enter a set of numbers")
        else:
            print()
            print("\t N=", len(lst))
            print("\t Min=", min(lst))
            print("\t Max=", max(lst))
            print("\t Range=", max(lst)-min(lst))
            print("\t Mean=", vf.co_mean(lst))
            print("\t STD=", vf.co_std(lst))
            print("\t STE=", vf.co_se(lst))
            print("\t Variance=", vf.co_var(lst))
            print()
    elif inp==9:
        break
    else:
        print("Input Invalid")
# Out:
# Press [0] to input a set of new numbers
# Press [1] to find the mean
# Press [2] to find the variance
# Press [3] to find the standard deviation
# Press [4] to find the standard error
# Press [5] to find the Z-score of a new observation
# Press [6] for the suammary of the statistics
# Press [9] to exit
